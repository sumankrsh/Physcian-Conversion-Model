# %% [markdown]
# #### Feature Store
#
# - Feature store is created in python script to avoid duplication. For your Understanding please refer to:
#
# Link : https://github.com/logicalclocks/hopsworks-tutorials/tree/master/fraud_batch/features

# %% [markdown]
# ![image.png](attachment:image.png)
#
#
# ![image-2.png](attachment:image-2.png)
